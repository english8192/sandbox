# %%
from icecream import ic

# %%
def step_deduction(steps):

    if steps >= 3 :
        deduction = 0
        init_deduction = 5
        rounds = steps - 3
        while rounds > -1:
            val =  (rounds*2)
            new_deduction = init_deduction+val
            rounds -= 1
            deduction += new_deduction
            #ic(val,deduction,rounds)
            

    else: deduction = 0
    return deduction

def time_deduction(seconds):
    if seconds-30 >=0:
        ded1= 30 * 0.05
        ded2= (seconds - 30) * 0.1
        deduction = ded1 + ded2
    else:
        deduction = seconds * 0.05
    return deduction

def get_score(time,steps):

    s_ded = step_deduction(steps)
    t_ded = time_deduction(time)
    # ic(s_ded)
    # ic(t_ded)
    score = 100-s_ded-t_ded

    return round(score,2)

# %%
print(f"Jared's Score: {get_score(27,4)} points")
print(f"Evans's Score: {get_score(118,4)} points")
# Out:
# Jared's Score: 86.65 points
# Evans's Score: 77.7 points
